# %%
from data.generate import generate_line_graph, generate_cube_graph
from utils.visualize import coord2scatter, plot_edge_index

import matplotlib.pyplot as plt

# %matplotlib inline

coords, edges = generate_line_graph(4)
fig = plt.figure(figsize=(8, 4), dpi=80)
fig.tight_layout()
ax1 = fig.add_subplot(121, projection='3d')
coord2scatter(coord=coords, title='Line', transparent=False, ax=ax1)
# plot_edge_index(edge_index=edges, coord=coords, title='Line', ax=ax1)

print ('Line:')
print (f'coords.shape: {coords.shape}')
print (f'coords:\n{coords}')
print (f'edges.shape: {edges.shape}')
print (f'edges:\n{edges}')

coords, edges = generate_cube_graph(4, 0.15)
fig = plt.figure(figsize=(8, 4), dpi=80)
fig.tight_layout()
ax2 = fig.add_subplot(121, projection='3d')
coord2scatter(coords, title='Cube', transparent=False, ax=ax2)
# plot_edge_index(edges, coords, title='Cube', ax=ax2)

print ('Cube:')
print (f'coords.shape: {coords.shape}')
print (f'edges.shape: {edges.shape}')
# Out:
# Line:
# coords.shape: torch.Size([4, 2])
# coords:
# tensor([[-1.1619, -1.1619],
#         [-0.3873, -0.3873],
#         [ 0.3873,  0.3873],
#         [ 1.1619,  1.1619]])
# edges.shape: torch.Size([2, 6])
# edges:
# tensor([[0, 1, 1, 2, 2, 3],
#         [1, 0, 2, 1, 3, 2]])
# Cube:
# coords.shape: torch.Size([64, 3])
# edges.shape: torch.Size([2, 0])
